# %%
from ultralytics import YOLO
import os
import torch
import tensorrt as trt

# %% [markdown]
# # torch quantization

# %%
import pickle
from torch.ao.quantization import quantize_dynamic

model_to_quant = torch.load("models/best.pt")
model_to_quant['model'] = quantize_dynamic(model_to_quant['model'].eval(), qconfig_spec=None, dtype=torch.quint8, mapping=None, inplace=False)

torch.save(model_to_quant, 'quant_models/best_int8.pt', pickle_module=pickle)
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")

# %%
torch_model = YOLO('quant_models/best_int8.pt')

# %% [markdown]
# ## model size

# %%
print('size : ' , round(os.path.getsize('quant_models/best_int8.pt')/1024) , 'KB')
# Out:
# size :  6097 KB

# %% [markdown]
# ## architecture

# %%
torch_model.model
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (3): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (4): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-1): 2 x Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (5): Conv(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (6): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0-1): 2 x Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (7): Conv(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (8): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (9): SPPF(
#       (cv1): Conv(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#     )
#     (10): Upsample(scale_factor=2.0, mode='nearest')
#     (11): Concat()
#     (12): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (13): Upsample(scale_factor=2.0, mode='nearest')
#     (14): Concat()
#     (15): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (16): Conv(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (17): Concat()
#     (18): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (19): Conv(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (20): Concat()
#     (21): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (m): ModuleList(
#         (0): Bottleneck(
#           (cv1): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#         )
#       )
#     )
#     (22): Detect(
#       (cv2): ModuleList(
#         (0): Sequential(
#           (0): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Sequential(
#           (0): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Sequential(
#           (0): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (cv3): ModuleList(
#         (0): Sequential(
#           (0): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Sequential(
#           (0): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Sequential(
#           (0): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (1): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#             (act): SiLU(inplace=True)
#           )
#           (2): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (dfl): DFL(
#         (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#     )
#   )
# )

# %% [markdown]
# ## parameters

# %%
for i in torch_model.model.fuse().parameters():
    print('first layer parameters \n\n ' , i.data)
    break
# Out:
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# first layer parameters
#
#   tensor([[[[-1.7560e+00, -2.7517e-01,  1.5227e+00],
#           [-5.8778e+00,  4.7612e-01,  6.0757e+00],
#           [-5.3064e+00, -2.7330e-01,  4.9405e+00]],
#
#          [[-1.9997e+00,  1.6081e-01,  2.2592e+00],
#           [-7.5843e+00,  4.6305e-01,  7.1511e+00],
#           [-5.7359e+00, -9.6099e-02,  5.3848e+00]],
#
#          [[-7.6133e-01, -3.8930e-01,  1.7014e-01],
#           [-3.5140e+00,  3.8510e-01,  2.9463e+00],
#           [-2.4908e+00,  3.1998e-01,  2.3619e+00]]],
#
#
#         [[[ 1.7665e+00,  1.6209e+00,  2.1402e+00],
#           [ 1.8290e-01, -2.4301e+00,  6.4909e-01],
#           [-2.3331e+00, -1.0133e+01, -1.3649e+00]],
#
#          [[-5.5658e-01, -5.4293e-01,  4.7529e-01],
#           [-2.4295e-01, -3.9043e+00, -7.0369e-01],
#           [-1.2484e+00, -1.1259e+01, -1.4729e+00]],
#
#          [[ 7.2310e-01, -1.7649e-02,  3.8945e-01],
#           [ 1.3176e+00, -1.3491e+00,  3.0392e-01],
#           [ 1.4353e+00, -4.9501e+00,  3.9218e-01]]],
#
#
#         [[[-9.3692e-02, -1.1119e+00, -4.2169e-01],
#           [-1.8066e+00, -3.8411e+00, -3.0417e+00],
#           [-1.4731e+00, -3.4121e+00, -2.8993e+00]],
#
#          [[ 1.4742e-02,  5.3083e-01,  1.9974e-01],
#           [ 4.8391e-01,  1.1388e+00,  8.4422e-01],
#           [ 3.0124e-01,  7.2481e-01,  5.9703e-01]],
#
#          [[ 9.2235e-01,  5.5592e-01,  1.4906e-01],
#           [-1.0175e-01, -1.2113e+00,  4.0667e-02],
#           [ 1.0469e-01, -3.6172e-01, -2.9288e-01]]],
#
#
#         [[[-2.5150e+00, -6.0051e+00, -3.6037e+00],
#           [-7.1069e-01, -8.5810e-01, -2.6208e-01],
#           [ 2.8708e+00,  6.3509e+00,  4.7599e+00]],
#
#          [[-2.5562e+00, -6.7726e+00, -3.8606e+00],
#           [-6.0693e-01, -9.2728e-01, -1.6789e-01],
#           [ 2.8098e+00,  6.4893e+00,  4.9477e+00]],
#
#          [[-6.9422e-01, -3.3023e+00, -1.4881e+00],
#           [-4.5746e-01, -7.2758e-01, -2.1782e-01],
#           [ 1.2921e+00,  3.3995e+00,  2.3091e+00]]],
#
#
#         [[[ 1.5728e+00,  1.7036e+00,  3.2522e-01],
#           [ 1.5125e+00,  1.8154e+00,  5.9532e-02],
#           [ 2.2949e-01, -4.6303e-02, -1.3376e+00]],
#
#          [[-1.9682e+00, -3.2250e+00, -1.6507e+00],
#           [-2.9443e+00, -4.0923e+00, -2.1431e+00],
#           [-1.2840e+00, -2.3489e+00, -7.4966e-01]],
#
#          [[ 2.1939e-01,  1.5272e+00,  1.0767e+00],
#           [ 9.7235e-01,  2.9193e+00,  2.3563e+00],
#           [ 8.3932e-01,  2.5092e+00,  2.2049e+00]]],
#
#
#         [[[ 3.8758e+00,  1.2895e+00,  1.5616e+00],
#           [ 2.3420e+00, -5.8200e+00, -1.0214e+01],
#           [ 5.2663e+00,  1.6706e+00,  3.7739e+00]],
#
#          [[-1.4669e+00, -7.4222e-01, -4.9998e-01],
#           [ 3.5003e-01, -2.4279e+00, -4.5440e+00],
#           [-1.1042e+00, -3.0532e+00, -2.1495e+00]],
#
#          [[-3.0898e+00, -4.6777e-01, -3.8758e+00],
#           [ 7.3864e-01,  2.5854e+00, -6.9330e-01],
#           [-1.3357e+00, -1.4431e+00, -3.5671e+00]]],
#
#
#         [[[ 4.0810e+00,  5.8438e+00,  4.7531e+00],
#           [-6.2496e+00, -1.4721e+01, -7.0460e+00],
#           [ 2.2269e+00,  4.9992e+00,  4.9079e+00]],
#
#          [[ 5.4735e+00,  6.3713e+00,  5.9757e+00],
#           [-7.6750e+00, -1.8881e+01, -8.8113e+00],
#           [ 4.6720e+00,  6.8837e+00,  6.7518e+00]],
#
#          [[ 1.8642e+00,  3.0842e+00,  1.3595e+00],
#           [-2.7088e+00, -7.4620e+00, -3.5864e+00],
#           [ 1.3062e+00,  3.5179e+00,  2.3195e+00]]],
#
#
#         [[[-5.3138e+00, -8.2660e+00, -6.3723e+00],
#           [ 8.0638e+00,  1.4904e+01,  1.0000e+01],
#           [-2.6383e+00, -6.4362e+00, -3.1330e+00]],
#
#          [[-1.7420e+00, -5.4362e+00, -3.0984e+00],
#           [ 7.7606e+00,  1.4606e+01,  9.3192e+00],
#           [-5.9628e+00, -1.0606e+01, -7.1330e+00]],
#
#          [[-2.2447e+00, -4.0851e+00, -3.1835e+00],
#           [ 3.6809e+00,  7.0745e+00,  4.7314e+00],
#           [-6.7852e-01, -3.5851e+00, -1.0406e+00]]],
#
#
#         [[[ 1.6810e+00, -9.7275e-02, -1.8102e+00],
#           [ 5.9490e+00,  5.7535e-01, -6.5130e+00],
#           [ 5.3378e+00,  2.6584e-01, -5.5961e+00]],
#
#          [[ 2.0885e+00,  7.4249e-02, -1.8393e+00],
#           [ 6.7277e+00,  2.5675e-01, -7.6555e+00],
#           [ 5.3960e+00,  5.7762e-01, -5.6689e+00]],
#
#          [[ 2.4310e-01, -2.7176e-01, -7.8729e-01],
#           [ 3.0091e+00,  2.6402e-01, -3.7204e+00],
#           [ 2.6361e+00,  6.4221e-01, -2.4360e+00]]],
#
#
#         [[[-5.2602e-01, -5.1966e-01, -1.1244e-01],
#           [-2.2042e-01,  7.6853e-01,  1.3565e+00],
#           [ 1.1498e-01,  1.6248e+00,  1.8651e+00]],
#
#          [[-5.4573e-01, -9.3444e-01, -4.0365e-01],
#           [-5.7243e-01, -8.7246e-02,  5.3873e-01],
#           [-5.8959e-02,  1.1862e+00,  1.5587e+00]],
#
#          [[ 1.9722e-01, -3.1069e-01, -1.3834e-01],
#           [-2.7541e-01,  2.4769e-03,  1.9515e-01],
#           [-4.1224e-01,  3.8141e-01,  2.7874e-01]]],
#
#
#         [[[-2.7670e-01, -7.4915e-01, -5.8657e-01],
#           [-7.3614e-01, -8.7726e-01, -7.6605e-01],
#           [-6.9257e-01, -1.0769e+00, -1.0463e+00]],
#
#          [[ 1.9158e+00,  2.3996e+00,  1.1666e+00],
#           [ 2.7937e+00,  3.8628e+00,  1.9184e+00],
#           [ 1.7545e+00,  2.2331e+00,  8.8246e-01]],
#
#          [[-1.6778e+00, -1.6856e+00, -9.3383e-01],
#           [-2.1863e+00, -2.0732e+00, -1.0470e+00],
#           [-1.2850e+00, -1.1393e+00, -1.3998e-01]]]])

# %% [markdown]
# # onnx quantization

# %%
from onnxruntime.quantization import quantize_dynamic, QuantType

model_onnx = 'models/best.onnx'
onnx_quant = 'quant_models/best.quant.onnx'

quantized_model = quantize_dynamic(model_onnx, onnx_quant)

# %%
import onnx

onnx_model = onnx.load('quant_models/best.quant.onnx')

# %% [markdown]
# ## model size

# %%
print('size : ' , round(os.path.getsize('quant_models/best.quant.onnx')/1024) , 'KB')
# Out:
# size :  3197 KB

# %% [markdown]
# ## architecture

# %%
onnx_model.graph.node
# Out:
# [input: "images"
# output: "images_quantized"
# output: "images_scale"
# output: "images_zero_point"
# name: "images_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "model.0.conv.bias"
# input: "/model.0/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.0/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.1.conv.bias"
# input: "/model.1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.12.cv1.conv.bias"
# input: "/model.12/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.12/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.12.cv2.conv.bias"
# input: "/model.12/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.12/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.12.m.0.cv1.conv.bias"
# input: "/model.12/m.0/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.12/m.0/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.12.m.0.cv2.conv.bias"
# input: "/model.12/m.0/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.12/m.0/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.15.cv1.conv.bias"
# input: "/model.15/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.15/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.15.cv2.conv.bias"
# input: "/model.15/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.15/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.15.m.0.cv1.conv.bias"
# input: "/model.15/m.0/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.15/m.0/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.15.m.0.cv2.conv.bias"
# input: "/model.15/m.0/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.15/m.0/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.16.conv.bias"
# input: "/model.16/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.16/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.18.cv1.conv.bias"
# input: "/model.18/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.18/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.18.cv2.conv.bias"
# input: "/model.18/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.18/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.18.m.0.cv1.conv.bias"
# input: "/model.18/m.0/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.18/m.0/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.18.m.0.cv2.conv.bias"
# input: "/model.18/m.0/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.18/m.0/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.19.conv.bias"
# input: "/model.19/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.19/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.2.cv1.conv.bias"
# input: "/model.2/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.2/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.2.cv2.conv.bias"
# input: "/model.2/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.2/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.2.m.0.cv1.conv.bias"
# input: "/model.2/m.0/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.2/m.0/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.2.m.0.cv2.conv.bias"
# input: "/model.2/m.0/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.2/m.0/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.21.cv1.conv.bias"
# input: "/model.21/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.21/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.21.cv2.conv.bias"
# input: "/model.21/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.21/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.21.m.0.cv1.conv.bias"
# input: "/model.21/m.0/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.21/m.0/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.21.m.0.cv2.conv.bias"
# input: "/model.21/m.0/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.21/m.0/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv2.0.0.conv.bias"
# input: "/model.22/cv2.0/cv2.0.0/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv2.0/cv2.0.0/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv2.0.1.conv.bias"
# input: "/model.22/cv2.0/cv2.0.1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv2.0/cv2.0.1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv2.0.2.bias"
# input: "/model.22/cv2.0/cv2.0.2/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv2.0/cv2.0.2/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv2.1.0.conv.bias"
# input: "/model.22/cv2.1/cv2.1.0/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv2.1/cv2.1.0/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv2.1.1.conv.bias"
# input: "/model.22/cv2.1/cv2.1.1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv2.1/cv2.1.1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv2.1.2.bias"
# input: "/model.22/cv2.1/cv2.1.2/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv2.1/cv2.1.2/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv2.2.0.conv.bias"
# input: "/model.22/cv2.2/cv2.2.0/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv2.2/cv2.2.0/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv2.2.1.conv.bias"
# input: "/model.22/cv2.2/cv2.2.1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv2.2/cv2.2.1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv2.2.2.bias"
# input: "/model.22/cv2.2/cv2.2.2/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv2.2/cv2.2.2/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv3.0.0.conv.bias"
# input: "/model.22/cv3.0/cv3.0.0/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv3.0/cv3.0.0/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv3.0.1.conv.bias"
# input: "/model.22/cv3.0/cv3.0.1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv3.0/cv3.0.1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv3.0.2.bias"
# input: "/model.22/cv3.0/cv3.0.2/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv3.0/cv3.0.2/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv3.1.0.conv.bias"
# input: "/model.22/cv3.1/cv3.1.0/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv3.1/cv3.1.0/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv3.1.1.conv.bias"
# input: "/model.22/cv3.1/cv3.1.1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv3.1/cv3.1.1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv3.1.2.bias"
# input: "/model.22/cv3.1/cv3.1.2/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv3.1/cv3.1.2/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv3.2.0.conv.bias"
# input: "/model.22/cv3.2/cv3.2.0/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv3.2/cv3.2.0/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv3.2.1.conv.bias"
# input: "/model.22/cv3.2/cv3.2.1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv3.2/cv3.2.1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.22.cv3.2.2.bias"
# input: "/model.22/cv3.2/cv3.2.2/Conv_output_0_bias_reshape_shape"
# output: "/model.22/cv3.2/cv3.2.2/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.3.conv.bias"
# input: "/model.3/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.3/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.4.cv1.conv.bias"
# input: "/model.4/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.4/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.4.cv2.conv.bias"
# input: "/model.4/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.4/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.4.m.0.cv1.conv.bias"
# input: "/model.4/m.0/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.4/m.0/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.4.m.0.cv2.conv.bias"
# input: "/model.4/m.0/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.4/m.0/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.4.m.1.cv1.conv.bias"
# input: "/model.4/m.1/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.4/m.1/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.4.m.1.cv2.conv.bias"
# input: "/model.4/m.1/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.4/m.1/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.5.conv.bias"
# input: "/model.5/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.5/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.6.cv1.conv.bias"
# input: "/model.6/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.6/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.6.cv2.conv.bias"
# input: "/model.6/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.6/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.6.m.0.cv1.conv.bias"
# input: "/model.6/m.0/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.6/m.0/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.6.m.0.cv2.conv.bias"
# input: "/model.6/m.0/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.6/m.0/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.6.m.1.cv1.conv.bias"
# input: "/model.6/m.1/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.6/m.1/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.6.m.1.cv2.conv.bias"
# input: "/model.6/m.1/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.6/m.1/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.7.conv.bias"
# input: "/model.7/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.7/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.8.cv1.conv.bias"
# input: "/model.8/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.8/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.8.cv2.conv.bias"
# input: "/model.8/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.8/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.8.m.0.cv1.conv.bias"
# input: "/model.8/m.0/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.8/m.0/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.8.m.0.cv2.conv.bias"
# input: "/model.8/m.0/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.8/m.0/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.9.cv1.conv.bias"
# input: "/model.9/cv1/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.9/cv1/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "model.9.cv2.conv.bias"
# input: "/model.9/cv2/conv/Conv_output_0_bias_reshape_shape"
# output: "/model.9/cv2/conv/Conv_output_0_bias_reshape_output"
# op_type: "Reshape"
# , input: "images_scale"
# input: "model.0.conv.weight_scale"
# output: "/model.0/conv/Conv_quant_scales_mul:0"
# name: "/model.0/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "images_quantized"
# input: "model.0.conv.weight_quantized"
# input: "images_zero_point"
# input: "model.0.conv.weight_zero_point"
# output: "/model.0/conv/Conv_output_0_output_quantized"
# name: "/model.0/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 3
#   ints: 3
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 2
#   ints: 2
# }
# , input: "/model.0/conv/Conv_output_0_output_quantized"
# output: "/model.0/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.0/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.0/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.0/conv/Conv_quant_scales_mul:0"
# output: "/model.0/conv/Conv_output_0quant_scaled_output"
# name: "/model.0/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.0/conv/Conv_output_0quant_scaled_output"
# input: "/model.0/conv/Conv_output_0_bias_reshape_output"
# output: "/model.0/conv/Conv_output_0"
# name: "/model.0/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.0/conv/Conv_output_0"
# output: "/model.0/act/Sigmoid_output_0"
# name: "/model.0/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.0/conv/Conv_output_0"
# input: "/model.0/act/Sigmoid_output_0"
# output: "/model.0/act/Mul_output_0"
# name: "/model.0/act/Mul"
# op_type: "Mul"
# , input: "/model.0/act/Mul_output_0"
# output: "/model.0/act/Mul_output_0_quantized"
# output: "/model.0/act/Mul_output_0_scale"
# output: "/model.0/act/Mul_output_0_zero_point"
# name: "/model.0/act/Mul_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.0/act/Mul_output_0_scale"
# input: "model.1.conv.weight_scale"
# output: "/model.1/conv/Conv_quant_scales_mul:0"
# name: "/model.1/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.0/act/Mul_output_0_quantized"
# input: "model.1.conv.weight_quantized"
# input: "/model.0/act/Mul_output_0_zero_point"
# input: "model.1.conv.weight_zero_point"
# output: "/model.1/conv/Conv_output_0_output_quantized"
# name: "/model.1/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 3
#   ints: 3
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 2
#   ints: 2
# }
# , input: "/model.1/conv/Conv_output_0_output_quantized"
# output: "/model.1/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.1/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.1/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.1/conv/Conv_quant_scales_mul:0"
# output: "/model.1/conv/Conv_output_0quant_scaled_output"
# name: "/model.1/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.1/conv/Conv_output_0quant_scaled_output"
# input: "/model.1/conv/Conv_output_0_bias_reshape_output"
# output: "/model.1/conv/Conv_output_0"
# name: "/model.1/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.1/conv/Conv_output_0"
# output: "/model.1/act/Sigmoid_output_0"
# name: "/model.1/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.1/conv/Conv_output_0"
# input: "/model.1/act/Sigmoid_output_0"
# output: "/model.1/act/Mul_output_0"
# name: "/model.1/act/Mul"
# op_type: "Mul"
# , input: "/model.1/act/Mul_output_0"
# output: "/model.1/act/Mul_output_0_quantized"
# output: "/model.1/act/Mul_output_0_scale"
# output: "/model.1/act/Mul_output_0_zero_point"
# name: "/model.1/act/Mul_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.1/act/Mul_output_0_scale"
# input: "model.2.cv1.conv.weight_scale"
# output: "/model.2/cv1/conv/Conv_quant_scales_mul:0"
# name: "/model.2/cv1/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.1/act/Mul_output_0_quantized"
# input: "model.2.cv1.conv.weight_quantized"
# input: "/model.1/act/Mul_output_0_zero_point"
# input: "model.2.cv1.conv.weight_zero_point"
# output: "/model.2/cv1/conv/Conv_output_0_output_quantized"
# name: "/model.2/cv1/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# , input: "/model.2/cv1/conv/Conv_output_0_output_quantized"
# output: "/model.2/cv1/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.2/cv1/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.2/cv1/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.2/cv1/conv/Conv_quant_scales_mul:0"
# output: "/model.2/cv1/conv/Conv_output_0quant_scaled_output"
# name: "/model.2/cv1/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.2/cv1/conv/Conv_output_0quant_scaled_output"
# input: "/model.2/cv1/conv/Conv_output_0_bias_reshape_output"
# output: "/model.2/cv1/conv/Conv_output_0"
# name: "/model.2/cv1/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.2/cv1/conv/Conv_output_0"
# output: "/model.2/cv1/act/Sigmoid_output_0"
# name: "/model.2/cv1/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.2/cv1/conv/Conv_output_0"
# input: "/model.2/cv1/act/Sigmoid_output_0"
# output: "/model.2/cv1/act/Mul_output_0"
# name: "/model.2/cv1/act/Mul"
# op_type: "Mul"
# , input: "/model.2/cv1/act/Mul_output_0"
# input: "onnx::Split_137"
# output: "/model.2/Split_output_0"
# output: "/model.2/Split_output_1"
# name: "/model.2/Split"
# op_type: "Split"
# attribute {
#   name: "axis"
#   type: INT
#   i: 1
# }
# , input: "/model.2/Split_output_1"
# output: "/model.2/Split_output_1_quantized"
# output: "/model.2/Split_output_1_scale"
# output: "/model.2/Split_output_1_zero_point"
# name: "/model.2/Split_output_1_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.2/Split_output_1_scale"
# input: "model.2.m.0.cv1.conv.weight_scale"
# output: "/model.2/m.0/cv1/conv/Conv_quant_scales_mul:0"
# name: "/model.2/m.0/cv1/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.2/Split_output_1_quantized"
# input: "model.2.m.0.cv1.conv.weight_quantized"
# input: "/model.2/Split_output_1_zero_point"
# input: "model.2.m.0.cv1.conv.weight_zero_point"
# output: "/model.2/m.0/cv1/conv/Conv_output_0_output_quantized"
# name: "/model.2/m.0/cv1/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 3
#   ints: 3
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# , input: "/model.2/m.0/cv1/conv/Conv_output_0_output_quantized"
# output: "/model.2/m.0/cv1/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.2/m.0/cv1/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.2/m.0/cv1/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.2/m.0/cv1/conv/Conv_quant_scales_mul:0"
# output: "/model.2/m.0/cv1/conv/Conv_output_0quant_scaled_output"
# name: "/model.2/m.0/cv1/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.2/m.0/cv1/conv/Conv_output_0quant_scaled_output"
# input: "/model.2/m.0/cv1/conv/Conv_output_0_bias_reshape_output"
# output: "/model.2/m.0/cv1/conv/Conv_output_0"
# name: "/model.2/m.0/cv1/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.2/m.0/cv1/conv/Conv_output_0"
# output: "/model.2/m.0/cv1/act/Sigmoid_output_0"
# name: "/model.2/m.0/cv1/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.2/m.0/cv1/conv/Conv_output_0"
# input: "/model.2/m.0/cv1/act/Sigmoid_output_0"
# output: "/model.2/m.0/cv1/act/Mul_output_0"
# name: "/model.2/m.0/cv1/act/Mul"
# op_type: "Mul"
# , input: "/model.2/m.0/cv1/act/Mul_output_0"
# output: "/model.2/m.0/cv1/act/Mul_output_0_quantized"
# output: "/model.2/m.0/cv1/act/Mul_output_0_scale"
# output: "/model.2/m.0/cv1/act/Mul_output_0_zero_point"
# name: "/model.2/m.0/cv1/act/Mul_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.2/m.0/cv1/act/Mul_output_0_scale"
# input: "model.2.m.0.cv2.conv.weight_scale"
# output: "/model.2/m.0/cv2/conv/Conv_quant_scales_mul:0"
# name: "/model.2/m.0/cv2/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.2/m.0/cv1/act/Mul_output_0_quantized"
# input: "model.2.m.0.cv2.conv.weight_quantized"
# input: "/model.2/m.0/cv1/act/Mul_output_0_zero_point"
# input: "model.2.m.0.cv2.conv.weight_zero_point"
# output: "/model.2/m.0/cv2/conv/Conv_output_0_output_quantized"
# name: "/model.2/m.0/cv2/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 3
#   ints: 3
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# , input: "/model.2/m.0/cv2/conv/Conv_output_0_output_quantized"
# output: "/model.2/m.0/cv2/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.2/m.0/cv2/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.2/m.0/cv2/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.2/m.0/cv2/conv/Conv_quant_scales_mul:0"
# output: "/model.2/m.0/cv2/conv/Conv_output_0quant_scaled_output"
# name: "/model.2/m.0/cv2/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.2/m.0/cv2/conv/Conv_output_0quant_scaled_output"
# input: "/model.2/m.0/cv2/conv/Conv_output_0_bias_reshape_output"
# output: "/model.2/m.0/cv2/conv/Conv_output_0"
# name: "/model.2/m.0/cv2/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.2/m.0/cv2/conv/Conv_output_0"
# output: "/model.2/m.0/cv2/act/Sigmoid_output_0"
# name: "/model.2/m.0/cv2/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.2/m.0/cv2/conv/Conv_output_0"
# input: "/model.2/m.0/cv2/act/Sigmoid_output_0"
# output: "/model.2/m.0/cv2/act/Mul_output_0"
# name: "/model.2/m.0/cv2/act/Mul"
# op_type: "Mul"
# , input: "/model.2/Split_output_1"
# input: "/model.2/m.0/cv2/act/Mul_output_0"
# output: "/model.2/m.0/Add_output_0"
# name: "/model.2/m.0/Add"
# op_type: "Add"
# , input: "/model.2/Split_output_0"
# input: "/model.2/Split_output_1"
# input: "/model.2/m.0/Add_output_0"
# output: "/model.2/Concat_output_0"
# name: "/model.2/Concat"
# op_type: "Concat"
# attribute {
#   name: "axis"
#   type: INT
#   i: 1
# }
# , input: "/model.2/Concat_output_0"
# output: "/model.2/Concat_output_0_quantized"
# output: "/model.2/Concat_output_0_scale"
# output: "/model.2/Concat_output_0_zero_point"
# name: "/model.2/Concat_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.2/Concat_output_0_scale"
# input: "model.2.cv2.conv.weight_scale"
# output: "/model.2/cv2/conv/Conv_quant_scales_mul:0"
# name: "/model.2/cv2/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.2/Concat_output_0_quantized"
# input: "model.2.cv2.conv.weight_quantized"
# input: "/model.2/Concat_output_0_zero_point"
# input: "model.2.cv2.conv.weight_zero_point"
# output: "/model.2/cv2/conv/Conv_output_0_output_quantized"
# name: "/model.2/cv2/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# , input: "/model.2/cv2/conv/Conv_output_0_output_quantized"
# output: "/model.2/cv2/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.2/cv2/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.2/cv2/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.2/cv2/conv/Conv_quant_scales_mul:0"
# output: "/model.2/cv2/conv/Conv_output_0quant_scaled_output"
# name: "/model.2/cv2/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.2/cv2/conv/Conv_output_0quant_scaled_output"
# input: "/model.2/cv2/conv/Conv_output_0_bias_reshape_output"
# output: "/model.2/cv2/conv/Conv_output_0"
# name: "/model.2/cv2/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.2/cv2/conv/Conv_output_0"
# output: "/model.2/cv2/act/Sigmoid_output_0"
# name: "/model.2/cv2/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.2/cv2/conv/Conv_output_0"
# input: "/model.2/cv2/act/Sigmoid_output_0"
# output: "/model.2/cv2/act/Mul_output_0"
# name: "/model.2/cv2/act/Mul"
# op_type: "Mul"
# , input: "/model.2/cv2/act/Mul_output_0"
# output: "/model.2/cv2/act/Mul_output_0_quantized"
# output: "/model.2/cv2/act/Mul_output_0_scale"
# output: "/model.2/cv2/act/Mul_output_0_zero_point"
# name: "/model.2/cv2/act/Mul_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.2/cv2/act/Mul_output_0_scale"
# input: "model.3.conv.weight_scale"
# output: "/model.3/conv/Conv_quant_scales_mul:0"
# name: "/model.3/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.2/cv2/act/Mul_output_0_quantized"
# input: "model.3.conv.weight_quantized"
# input: "/model.2/cv2/act/Mul_output_0_zero_point"
# input: "model.3.conv.weight_zero_point"
# output: "/model.3/conv/Conv_output_0_output_quantized"
# name: "/model.3/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 3
#   ints: 3
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 2
#   ints: 2
# }
# , input: "/model.3/conv/Conv_output_0_output_quantized"
# output: "/model.3/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.3/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.3/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.3/conv/Conv_quant_scales_mul:0"
# output: "/model.3/conv/Conv_output_0quant_scaled_output"
# name: "/model.3/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.3/conv/Conv_output_0quant_scaled_output"
# input: "/model.3/conv/Conv_output_0_bias_reshape_output"
# output: "/model.3/conv/Conv_output_0"
# name: "/model.3/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.3/conv/Conv_output_0"
# output: "/model.3/act/Sigmoid_output_0"
# name: "/model.3/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.3/conv/Conv_output_0"
# input: "/model.3/act/Sigmoid_output_0"
# output: "/model.3/act/Mul_output_0"
# name: "/model.3/act/Mul"
# op_type: "Mul"
# , input: "/model.3/act/Mul_output_0"
# output: "/model.3/act/Mul_output_0_quantized"
# output: "/model.3/act/Mul_output_0_scale"
# output: "/model.3/act/Mul_output_0_zero_point"
# name: "/model.3/act/Mul_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.3/act/Mul_output_0_scale"
# input: "model.4.cv1.conv.weight_scale"
# output: "/model.4/cv1/conv/Conv_quant_scales_mul:0"
# name: "/model.4/cv1/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.3/act/Mul_output_0_quantized"
# input: "model.4.cv1.conv.weight_quantized"
# input: "/model.3/act/Mul_output_0_zero_point"
# input: "model.4.cv1.conv.weight_zero_point"
# output: "/model.4/cv1/conv/Conv_output_0_output_quantized"
# name: "/model.4/cv1/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# , input: "/model.4/cv1/conv/Conv_output_0_output_quantized"
# output: "/model.4/cv1/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.4/cv1/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.4/cv1/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.4/cv1/conv/Conv_quant_scales_mul:0"
# output: "/model.4/cv1/conv/Conv_output_0quant_scaled_output"
# name: "/model.4/cv1/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.4/cv1/conv/Conv_output_0quant_scaled_output"
# input: "/model.4/cv1/conv/Conv_output_0_bias_reshape_output"
# output: "/model.4/cv1/conv/Conv_output_0"
# name: "/model.4/cv1/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.4/cv1/conv/Conv_output_0"
# output: "/model.4/cv1/act/Sigmoid_output_0"
# name: "/model.4/cv1/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.4/cv1/conv/Conv_output_0"
# input: "/model.4/cv1/act/Sigmoid_output_0"
# output: "/model.4/cv1/act/Mul_output_0"
# name: "/model.4/cv1/act/Mul"
# op_type: "Mul"
# , input: "/model.4/cv1/act/Mul_output_0"
# input: "onnx::Split_157"
# output: "/model.4/Split_output_0"
# output: "/model.4/Split_output_1"
# name: "/model.4/Split"
# op_type: "Split"
# attribute {
#   name: "axis"
#   type: INT
#   i: 1
# }
# , input: "/model.4/Split_output_1"
# output: "/model.4/Split_output_1_quantized"
# output: "/model.4/Split_output_1_scale"
# output: "/model.4/Split_output_1_zero_point"
# name: "/model.4/Split_output_1_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.4/Split_output_1_scale"
# input: "model.4.m.0.cv1.conv.weight_scale"
# output: "/model.4/m.0/cv1/conv/Conv_quant_scales_mul:0"
# name: "/model.4/m.0/cv1/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.4/Split_output_1_quantized"
# input: "model.4.m.0.cv1.conv.weight_quantized"
# input: "/model.4/Split_output_1_zero_point"
# input: "model.4.m.0.cv1.conv.weight_zero_point"
# output: "/model.4/m.0/cv1/conv/Conv_output_0_output_quantized"
# name: "/model.4/m.0/cv1/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 3
#   ints: 3
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# , input: "/model.4/m.0/cv1/conv/Conv_output_0_output_quantized"
# output: "/model.4/m.0/cv1/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.4/m.0/cv1/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.4/m.0/cv1/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.4/m.0/cv1/conv/Conv_quant_scales_mul:0"
# output: "/model.4/m.0/cv1/conv/Conv_output_0quant_scaled_output"
# name: "/model.4/m.0/cv1/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.4/m.0/cv1/conv/Conv_output_0quant_scaled_output"
# input: "/model.4/m.0/cv1/conv/Conv_output_0_bias_reshape_output"
# output: "/model.4/m.0/cv1/conv/Conv_output_0"
# name: "/model.4/m.0/cv1/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.4/m.0/cv1/conv/Conv_output_0"
# output: "/model.4/m.0/cv1/act/Sigmoid_output_0"
# name: "/model.4/m.0/cv1/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.4/m.0/cv1/conv/Conv_output_0"
# input: "/model.4/m.0/cv1/act/Sigmoid_output_0"
# output: "/model.4/m.0/cv1/act/Mul_output_0"
# name: "/model.4/m.0/cv1/act/Mul"
# op_type: "Mul"
# , input: "/model.4/m.0/cv1/act/Mul_output_0"
# output: "/model.4/m.0/cv1/act/Mul_output_0_quantized"
# output: "/model.4/m.0/cv1/act/Mul_output_0_scale"
# output: "/model.4/m.0/cv1/act/Mul_output_0_zero_point"
# name: "/model.4/m.0/cv1/act/Mul_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.4/m.0/cv1/act/Mul_output_0_scale"
# input: "model.4.m.0.cv2.conv.weight_scale"
# output: "/model.4/m.0/cv2/conv/Conv_quant_scales_mul:0"
# name: "/model.4/m.0/cv2/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.4/m.0/cv1/act/Mul_output_0_quantized"
# input: "model.4.m.0.cv2.conv.weight_quantized"
# input: "/model.4/m.0/cv1/act/Mul_output_0_zero_point"
# input: "model.4.m.0.cv2.conv.weight_zero_point"
# output: "/model.4/m.0/cv2/conv/Conv_output_0_output_quantized"
# name: "/model.4/m.0/cv2/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 3
#   ints: 3
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# , input: "/model.4/m.0/cv2/conv/Conv_output_0_output_quantized"
# output: "/model.4/m.0/cv2/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.4/m.0/cv2/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.4/m.0/cv2/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.4/m.0/cv2/conv/Conv_quant_scales_mul:0"
# output: "/model.4/m.0/cv2/conv/Conv_output_0quant_scaled_output"
# name: "/model.4/m.0/cv2/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.4/m.0/cv2/conv/Conv_output_0quant_scaled_output"
# input: "/model.4/m.0/cv2/conv/Conv_output_0_bias_reshape_output"
# output: "/model.4/m.0/cv2/conv/Conv_output_0"
# name: "/model.4/m.0/cv2/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.4/m.0/cv2/conv/Conv_output_0"
# output: "/model.4/m.0/cv2/act/Sigmoid_output_0"
# name: "/model.4/m.0/cv2/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.4/m.0/cv2/conv/Conv_output_0"
# input: "/model.4/m.0/cv2/act/Sigmoid_output_0"
# output: "/model.4/m.0/cv2/act/Mul_output_0"
# name: "/model.4/m.0/cv2/act/Mul"
# op_type: "Mul"
# , input: "/model.4/Split_output_1"
# input: "/model.4/m.0/cv2/act/Mul_output_0"
# output: "/model.4/m.0/Add_output_0"
# name: "/model.4/m.0/Add"
# op_type: "Add"
# , input: "/model.4/m.0/Add_output_0"
# output: "/model.4/m.0/Add_output_0_quantized"
# output: "/model.4/m.0/Add_output_0_scale"
# output: "/model.4/m.0/Add_output_0_zero_point"
# name: "/model.4/m.0/Add_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.4/m.0/Add_output_0_scale"
# input: "model.4.m.1.cv1.conv.weight_scale"
# output: "/model.4/m.1/cv1/conv/Conv_quant_scales_mul:0"
# name: "/model.4/m.1/cv1/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.4/m.0/Add_output_0_quantized"
# input: "model.4.m.1.cv1.conv.weight_quantized"
# input: "/model.4/m.0/Add_output_0_zero_point"
# input: "model.4.m.1.cv1.conv.weight_zero_point"
# output: "/model.4/m.1/cv1/conv/Conv_output_0_output_quantized"
# name: "/model.4/m.1/cv1/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 3
#   ints: 3
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# , input: "/model.4/m.1/cv1/conv/Conv_output_0_output_quantized"
# output: "/model.4/m.1/cv1/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.4/m.1/cv1/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.4/m.1/cv1/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.4/m.1/cv1/conv/Conv_quant_scales_mul:0"
# output: "/model.4/m.1/cv1/conv/Conv_output_0quant_scaled_output"
# name: "/model.4/m.1/cv1/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.4/m.1/cv1/conv/Conv_output_0quant_scaled_output"
# input: "/model.4/m.1/cv1/conv/Conv_output_0_bias_reshape_output"
# output: "/model.4/m.1/cv1/conv/Conv_output_0"
# name: "/model.4/m.1/cv1/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.4/m.1/cv1/conv/Conv_output_0"
# output: "/model.4/m.1/cv1/act/Sigmoid_output_0"
# name: "/model.4/m.1/cv1/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.4/m.1/cv1/conv/Conv_output_0"
# input: "/model.4/m.1/cv1/act/Sigmoid_output_0"
# output: "/model.4/m.1/cv1/act/Mul_output_0"
# name: "/model.4/m.1/cv1/act/Mul"
# op_type: "Mul"
# , input: "/model.4/m.1/cv1/act/Mul_output_0"
# output: "/model.4/m.1/cv1/act/Mul_output_0_quantized"
# output: "/model.4/m.1/cv1/act/Mul_output_0_scale"
# output: "/model.4/m.1/cv1/act/Mul_output_0_zero_point"
# name: "/model.4/m.1/cv1/act/Mul_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.4/m.1/cv1/act/Mul_output_0_scale"
# input: "model.4.m.1.cv2.conv.weight_scale"
# output: "/model.4/m.1/cv2/conv/Conv_quant_scales_mul:0"
# name: "/model.4/m.1/cv2/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.4/m.1/cv1/act/Mul_output_0_quantized"
# input: "model.4.m.1.cv2.conv.weight_quantized"
# input: "/model.4/m.1/cv1/act/Mul_output_0_zero_point"
# input: "model.4.m.1.cv2.conv.weight_zero_point"
# output: "/model.4/m.1/cv2/conv/Conv_output_0_output_quantized"
# name: "/model.4/m.1/cv2/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 3
#   ints: 3
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# , input: "/model.4/m.1/cv2/conv/Conv_output_0_output_quantized"
# output: "/model.4/m.1/cv2/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.4/m.1/cv2/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.4/m.1/cv2/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.4/m.1/cv2/conv/Conv_quant_scales_mul:0"
# output: "/model.4/m.1/cv2/conv/Conv_output_0quant_scaled_output"
# name: "/model.4/m.1/cv2/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.4/m.1/cv2/conv/Conv_output_0quant_scaled_output"
# input: "/model.4/m.1/cv2/conv/Conv_output_0_bias_reshape_output"
# output: "/model.4/m.1/cv2/conv/Conv_output_0"
# name: "/model.4/m.1/cv2/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.4/m.1/cv2/conv/Conv_output_0"
# output: "/model.4/m.1/cv2/act/Sigmoid_output_0"
# name: "/model.4/m.1/cv2/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.4/m.1/cv2/conv/Conv_output_0"
# input: "/model.4/m.1/cv2/act/Sigmoid_output_0"
# output: "/model.4/m.1/cv2/act/Mul_output_0"
# name: "/model.4/m.1/cv2/act/Mul"
# op_type: "Mul"
# , input: "/model.4/m.0/Add_output_0"
# input: "/model.4/m.1/cv2/act/Mul_output_0"
# output: "/model.4/m.1/Add_output_0"
# name: "/model.4/m.1/Add"
# op_type: "Add"
# , input: "/model.4/Split_output_0"
# input: "/model.4/Split_output_1"
# input: "/model.4/m.0/Add_output_0"
# input: "/model.4/m.1/Add_output_0"
# output: "/model.4/Concat_output_0"
# name: "/model.4/Concat"
# op_type: "Concat"
# attribute {
#   name: "axis"
#   type: INT
#   i: 1
# }
# , input: "/model.4/Concat_output_0"
# output: "/model.4/Concat_output_0_quantized"
# output: "/model.4/Concat_output_0_scale"
# output: "/model.4/Concat_output_0_zero_point"
# name: "/model.4/Concat_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.4/Concat_output_0_scale"
# input: "model.4.cv2.conv.weight_scale"
# output: "/model.4/cv2/conv/Conv_quant_scales_mul:0"
# name: "/model.4/cv2/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.4/Concat_output_0_quantized"
# input: "model.4.cv2.conv.weight_quantized"
# input: "/model.4/Concat_output_0_zero_point"
# input: "model.4.cv2.conv.weight_zero_point"
# output: "/model.4/cv2/conv/Conv_output_0_output_quantized"
# name: "/model.4/cv2/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# , input: "/model.4/cv2/conv/Conv_output_0_output_quantized"
# output: "/model.4/cv2/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.4/cv2/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.4/cv2/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.4/cv2/conv/Conv_quant_scales_mul:0"
# output: "/model.4/cv2/conv/Conv_output_0quant_scaled_output"
# name: "/model.4/cv2/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.4/cv2/conv/Conv_output_0quant_scaled_output"
# input: "/model.4/cv2/conv/Conv_output_0_bias_reshape_output"
# output: "/model.4/cv2/conv/Conv_output_0"
# name: "/model.4/cv2/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.4/cv2/conv/Conv_output_0"
# output: "/model.4/cv2/act/Sigmoid_output_0"
# name: "/model.4/cv2/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.4/cv2/conv/Conv_output_0"
# input: "/model.4/cv2/act/Sigmoid_output_0"
# output: "/model.4/cv2/act/Mul_output_0"
# name: "/model.4/cv2/act/Mul"
# op_type: "Mul"
# , input: "/model.4/cv2/act/Mul_output_0"
# output: "/model.4/cv2/act/Mul_output_0_quantized"
# output: "/model.4/cv2/act/Mul_output_0_scale"
# output: "/model.4/cv2/act/Mul_output_0_zero_point"
# name: "/model.4/cv2/act/Mul_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.4/cv2/act/Mul_output_0_scale"
# input: "model.5.conv.weight_scale"
# output: "/model.5/conv/Conv_quant_scales_mul:0"
# name: "/model.5/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.4/cv2/act/Mul_output_0_quantized"
# input: "model.5.conv.weight_quantized"
# input: "/model.4/cv2/act/Mul_output_0_zero_point"
# input: "model.5.conv.weight_zero_point"
# output: "/model.5/conv/Conv_output_0_output_quantized"
# name: "/model.5/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 3
#   ints: 3
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 2
#   ints: 2
# }
# , input: "/model.5/conv/Conv_output_0_output_quantized"
# output: "/model.5/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.5/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.5/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.5/conv/Conv_quant_scales_mul:0"
# output: "/model.5/conv/Conv_output_0quant_scaled_output"
# name: "/model.5/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.5/conv/Conv_output_0quant_scaled_output"
# input: "/model.5/conv/Conv_output_0_bias_reshape_output"
# output: "/model.5/conv/Conv_output_0"
# name: "/model.5/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.5/conv/Conv_output_0"
# output: "/model.5/act/Sigmoid_output_0"
# name: "/model.5/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.5/conv/Conv_output_0"
# input: "/model.5/act/Sigmoid_output_0"
# output: "/model.5/act/Mul_output_0"
# name: "/model.5/act/Mul"
# op_type: "Mul"
# , input: "/model.5/act/Mul_output_0"
# output: "/model.5/act/Mul_output_0_quantized"
# output: "/model.5/act/Mul_output_0_scale"
# output: "/model.5/act/Mul_output_0_zero_point"
# name: "/model.5/act/Mul_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.5/act/Mul_output_0_scale"
# input: "model.6.cv1.conv.weight_scale"
# output: "/model.6/cv1/conv/Conv_quant_scales_mul:0"
# name: "/model.6/cv1/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.5/act/Mul_output_0_quantized"
# input: "model.6.cv1.conv.weight_quantized"
# input: "/model.5/act/Mul_output_0_zero_point"
# input: "model.6.cv1.conv.weight_zero_point"
# output: "/model.6/cv1/conv/Conv_output_0_output_quantized"
# name: "/model.6/cv1/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# , input: "/model.6/cv1/conv/Conv_output_0_output_quantized"
# output: "/model.6/cv1/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.6/cv1/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.6/cv1/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.6/cv1/conv/Conv_quant_scales_mul:0"
# output: "/model.6/cv1/conv/Conv_output_0quant_scaled_output"
# name: "/model.6/cv1/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.6/cv1/conv/Conv_output_0quant_scaled_output"
# input: "/model.6/cv1/conv/Conv_output_0_bias_reshape_output"
# output: "/model.6/cv1/conv/Conv_output_0"
# name: "/model.6/cv1/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.6/cv1/conv/Conv_output_0"
# output: "/model.6/cv1/act/Sigmoid_output_0"
# name: "/model.6/cv1/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.6/cv1/conv/Conv_output_0"
# input: "/model.6/cv1/act/Sigmoid_output_0"
# output: "/model.6/cv1/act/Mul_output_0"
# name: "/model.6/cv1/act/Mul"
# op_type: "Mul"
# , input: "/model.6/cv1/act/Mul_output_0"
# input: "onnx::Split_184"
# output: "/model.6/Split_output_0"
# output: "/model.6/Split_output_1"
# name: "/model.6/Split"
# op_type: "Split"
# attribute {
#   name: "axis"
#   type: INT
#   i: 1
# }
# , input: "/model.6/Split_output_1"
# output: "/model.6/Split_output_1_quantized"
# output: "/model.6/Split_output_1_scale"
# output: "/model.6/Split_output_1_zero_point"
# name: "/model.6/Split_output_1_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.6/Split_output_1_scale"
# input: "model.6.m.0.cv1.conv.weight_scale"
# output: "/model.6/m.0/cv1/conv/Conv_quant_scales_mul:0"
# name: "/model.6/m.0/cv1/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.6/Split_output_1_quantized"
# input: "model.6.m.0.cv1.conv.weight_quantized"
# input: "/model.6/Split_output_1_zero_point"
# input: "model.6.m.0.cv1.conv.weight_zero_point"
# output: "/model.6/m.0/cv1/conv/Conv_output_0_output_quantized"
# name: "/model.6/m.0/cv1/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 3
#   ints: 3
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# , input: "/model.6/m.0/cv1/conv/Conv_output_0_output_quantized"
# output: "/model.6/m.0/cv1/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.6/m.0/cv1/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.6/m.0/cv1/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.6/m.0/cv1/conv/Conv_quant_scales_mul:0"
# output: "/model.6/m.0/cv1/conv/Conv_output_0quant_scaled_output"
# name: "/model.6/m.0/cv1/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.6/m.0/cv1/conv/Conv_output_0quant_scaled_output"
# input: "/model.6/m.0/cv1/conv/Conv_output_0_bias_reshape_output"
# output: "/model.6/m.0/cv1/conv/Conv_output_0"
# name: "/model.6/m.0/cv1/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.6/m.0/cv1/conv/Conv_output_0"
# output: "/model.6/m.0/cv1/act/Sigmoid_output_0"
# name: "/model.6/m.0/cv1/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.6/m.0/cv1/conv/Conv_output_0"
# input: "/model.6/m.0/cv1/act/Sigmoid_output_0"
# output: "/model.6/m.0/cv1/act/Mul_output_0"
# name: "/model.6/m.0/cv1/act/Mul"
# op_type: "Mul"
# , input: "/model.6/m.0/cv1/act/Mul_output_0"
# output: "/model.6/m.0/cv1/act/Mul_output_0_quantized"
# output: "/model.6/m.0/cv1/act/Mul_output_0_scale"
# output: "/model.6/m.0/cv1/act/Mul_output_0_zero_point"
# name: "/model.6/m.0/cv1/act/Mul_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.6/m.0/cv1/act/Mul_output_0_scale"
# input: "model.6.m.0.cv2.conv.weight_scale"
# ...
# op_type: "Mul"
# , input: "/model.22/cv3.2/cv3.2.0/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.22/cv3.2/cv3.2.0/conv/Conv_quant_scales_mul:0"
# output: "/model.22/cv3.2/cv3.2.0/conv/Conv_output_0quant_scaled_output"
# name: "/model.22/cv3.2/cv3.2.0/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.22/cv2.2/cv2.2.0/conv/Conv_output_0quant_scaled_output"
# input: "/model.22/cv2.2/cv2.2.0/conv/Conv_output_0_bias_reshape_output"
# output: "/model.22/cv2.2/cv2.2.0/conv/Conv_output_0"
# name: "/model.22/cv2.2/cv2.2.0/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.22/cv3.2/cv3.2.0/conv/Conv_output_0quant_scaled_output"
# input: "/model.22/cv3.2/cv3.2.0/conv/Conv_output_0_bias_reshape_output"
# output: "/model.22/cv3.2/cv3.2.0/conv/Conv_output_0"
# name: "/model.22/cv3.2/cv3.2.0/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.22/cv2.2/cv2.2.0/conv/Conv_output_0"
# output: "/model.22/cv2.2/cv2.2.0/act/Sigmoid_output_0"
# name: "/model.22/cv2.2/cv2.2.0/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.22/cv3.2/cv3.2.0/conv/Conv_output_0"
# output: "/model.22/cv3.2/cv3.2.0/act/Sigmoid_output_0"
# name: "/model.22/cv3.2/cv3.2.0/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.22/cv2.2/cv2.2.0/conv/Conv_output_0"
# input: "/model.22/cv2.2/cv2.2.0/act/Sigmoid_output_0"
# output: "/model.22/cv2.2/cv2.2.0/act/Mul_output_0"
# name: "/model.22/cv2.2/cv2.2.0/act/Mul"
# op_type: "Mul"
# , input: "/model.22/cv3.2/cv3.2.0/conv/Conv_output_0"
# input: "/model.22/cv3.2/cv3.2.0/act/Sigmoid_output_0"
# output: "/model.22/cv3.2/cv3.2.0/act/Mul_output_0"
# name: "/model.22/cv3.2/cv3.2.0/act/Mul"
# op_type: "Mul"
# , input: "/model.22/cv2.2/cv2.2.0/act/Mul_output_0"
# output: "/model.22/cv2.2/cv2.2.0/act/Mul_output_0_quantized"
# output: "/model.22/cv2.2/cv2.2.0/act/Mul_output_0_scale"
# output: "/model.22/cv2.2/cv2.2.0/act/Mul_output_0_zero_point"
# name: "/model.22/cv2.2/cv2.2.0/act/Mul_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.22/cv3.2/cv3.2.0/act/Mul_output_0"
# output: "/model.22/cv3.2/cv3.2.0/act/Mul_output_0_quantized"
# output: "/model.22/cv3.2/cv3.2.0/act/Mul_output_0_scale"
# output: "/model.22/cv3.2/cv3.2.0/act/Mul_output_0_zero_point"
# name: "/model.22/cv3.2/cv3.2.0/act/Mul_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.22/cv2.2/cv2.2.0/act/Mul_output_0_scale"
# input: "model.22.cv2.2.1.conv.weight_scale"
# output: "/model.22/cv2.2/cv2.2.1/conv/Conv_quant_scales_mul:0"
# name: "/model.22/cv2.2/cv2.2.1/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.22/cv2.2/cv2.2.0/act/Mul_output_0_quantized"
# input: "model.22.cv2.2.1.conv.weight_quantized"
# input: "/model.22/cv2.2/cv2.2.0/act/Mul_output_0_zero_point"
# input: "model.22.cv2.2.1.conv.weight_zero_point"
# output: "/model.22/cv2.2/cv2.2.1/conv/Conv_output_0_output_quantized"
# name: "/model.22/cv2.2/cv2.2.1/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 3
#   ints: 3
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# , input: "/model.22/cv3.2/cv3.2.0/act/Mul_output_0_scale"
# input: "model.22.cv3.2.1.conv.weight_scale"
# output: "/model.22/cv3.2/cv3.2.1/conv/Conv_quant_scales_mul:0"
# name: "/model.22/cv3.2/cv3.2.1/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.22/cv3.2/cv3.2.0/act/Mul_output_0_quantized"
# input: "model.22.cv3.2.1.conv.weight_quantized"
# input: "/model.22/cv3.2/cv3.2.0/act/Mul_output_0_zero_point"
# input: "model.22.cv3.2.1.conv.weight_zero_point"
# output: "/model.22/cv3.2/cv3.2.1/conv/Conv_output_0_output_quantized"
# name: "/model.22/cv3.2/cv3.2.1/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 3
#   ints: 3
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# , input: "/model.22/cv2.2/cv2.2.1/conv/Conv_output_0_output_quantized"
# output: "/model.22/cv2.2/cv2.2.1/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.22/cv2.2/cv2.2.1/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.22/cv3.2/cv3.2.1/conv/Conv_output_0_output_quantized"
# output: "/model.22/cv3.2/cv3.2.1/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.22/cv3.2/cv3.2.1/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.22/cv2.2/cv2.2.1/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.22/cv2.2/cv2.2.1/conv/Conv_quant_scales_mul:0"
# output: "/model.22/cv2.2/cv2.2.1/conv/Conv_output_0quant_scaled_output"
# name: "/model.22/cv2.2/cv2.2.1/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.22/cv3.2/cv3.2.1/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.22/cv3.2/cv3.2.1/conv/Conv_quant_scales_mul:0"
# output: "/model.22/cv3.2/cv3.2.1/conv/Conv_output_0quant_scaled_output"
# name: "/model.22/cv3.2/cv3.2.1/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.22/cv2.2/cv2.2.1/conv/Conv_output_0quant_scaled_output"
# input: "/model.22/cv2.2/cv2.2.1/conv/Conv_output_0_bias_reshape_output"
# output: "/model.22/cv2.2/cv2.2.1/conv/Conv_output_0"
# name: "/model.22/cv2.2/cv2.2.1/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.22/cv3.2/cv3.2.1/conv/Conv_output_0quant_scaled_output"
# input: "/model.22/cv3.2/cv3.2.1/conv/Conv_output_0_bias_reshape_output"
# output: "/model.22/cv3.2/cv3.2.1/conv/Conv_output_0"
# name: "/model.22/cv3.2/cv3.2.1/conv/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.22/cv2.2/cv2.2.1/conv/Conv_output_0"
# output: "/model.22/cv2.2/cv2.2.1/act/Sigmoid_output_0"
# name: "/model.22/cv2.2/cv2.2.1/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.22/cv3.2/cv3.2.1/conv/Conv_output_0"
# output: "/model.22/cv3.2/cv3.2.1/act/Sigmoid_output_0"
# name: "/model.22/cv3.2/cv3.2.1/act/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.22/cv2.2/cv2.2.1/conv/Conv_output_0"
# input: "/model.22/cv2.2/cv2.2.1/act/Sigmoid_output_0"
# output: "/model.22/cv2.2/cv2.2.1/act/Mul_output_0"
# name: "/model.22/cv2.2/cv2.2.1/act/Mul"
# op_type: "Mul"
# , input: "/model.22/cv3.2/cv3.2.1/conv/Conv_output_0"
# input: "/model.22/cv3.2/cv3.2.1/act/Sigmoid_output_0"
# output: "/model.22/cv3.2/cv3.2.1/act/Mul_output_0"
# name: "/model.22/cv3.2/cv3.2.1/act/Mul"
# op_type: "Mul"
# , input: "/model.22/cv2.2/cv2.2.1/act/Mul_output_0"
# output: "/model.22/cv2.2/cv2.2.1/act/Mul_output_0_quantized"
# output: "/model.22/cv2.2/cv2.2.1/act/Mul_output_0_scale"
# output: "/model.22/cv2.2/cv2.2.1/act/Mul_output_0_zero_point"
# name: "/model.22/cv2.2/cv2.2.1/act/Mul_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.22/cv3.2/cv3.2.1/act/Mul_output_0"
# output: "/model.22/cv3.2/cv3.2.1/act/Mul_output_0_quantized"
# output: "/model.22/cv3.2/cv3.2.1/act/Mul_output_0_scale"
# output: "/model.22/cv3.2/cv3.2.1/act/Mul_output_0_zero_point"
# name: "/model.22/cv3.2/cv3.2.1/act/Mul_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.22/cv2.2/cv2.2.1/act/Mul_output_0_scale"
# input: "model.22.cv2.2.2.weight_scale"
# output: "/model.22/cv2.2/cv2.2.2/Conv_quant_scales_mul:0"
# name: "/model.22/cv2.2/cv2.2.2/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.22/cv2.2/cv2.2.1/act/Mul_output_0_quantized"
# input: "model.22.cv2.2.2.weight_quantized"
# input: "/model.22/cv2.2/cv2.2.1/act/Mul_output_0_zero_point"
# input: "model.22.cv2.2.2.weight_zero_point"
# output: "/model.22/cv2.2/cv2.2.2/Conv_output_0_output_quantized"
# name: "/model.22/cv2.2/cv2.2.2/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# , input: "/model.22/cv3.2/cv3.2.1/act/Mul_output_0_scale"
# input: "model.22.cv3.2.2.weight_scale"
# output: "/model.22/cv3.2/cv3.2.2/Conv_quant_scales_mul:0"
# name: "/model.22/cv3.2/cv3.2.2/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.22/cv3.2/cv3.2.1/act/Mul_output_0_quantized"
# input: "model.22.cv3.2.2.weight_quantized"
# input: "/model.22/cv3.2/cv3.2.1/act/Mul_output_0_zero_point"
# input: "model.22.cv3.2.2.weight_zero_point"
# output: "/model.22/cv3.2/cv3.2.2/Conv_output_0_output_quantized"
# name: "/model.22/cv3.2/cv3.2.2/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# , input: "/model.22/cv2.2/cv2.2.2/Conv_output_0_output_quantized"
# output: "/model.22/cv2.2/cv2.2.2/Conv_output_0_output_quantized_cast_output"
# name: "/model.22/cv2.2/cv2.2.2/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.22/cv3.2/cv3.2.2/Conv_output_0_output_quantized"
# output: "/model.22/cv3.2/cv3.2.2/Conv_output_0_output_quantized_cast_output"
# name: "/model.22/cv3.2/cv3.2.2/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.22/cv2.2/cv2.2.2/Conv_output_0_output_quantized_cast_output"
# input: "/model.22/cv2.2/cv2.2.2/Conv_quant_scales_mul:0"
# output: "/model.22/cv2.2/cv2.2.2/Conv_output_0quant_scaled_output"
# name: "/model.22/cv2.2/cv2.2.2/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.22/cv3.2/cv3.2.2/Conv_output_0_output_quantized_cast_output"
# input: "/model.22/cv3.2/cv3.2.2/Conv_quant_scales_mul:0"
# output: "/model.22/cv3.2/cv3.2.2/Conv_output_0quant_scaled_output"
# name: "/model.22/cv3.2/cv3.2.2/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.22/cv2.2/cv2.2.2/Conv_output_0quant_scaled_output"
# input: "/model.22/cv2.2/cv2.2.2/Conv_output_0_bias_reshape_output"
# output: "/model.22/cv2.2/cv2.2.2/Conv_output_0"
# name: "/model.22/cv2.2/cv2.2.2/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.22/cv3.2/cv3.2.2/Conv_output_0quant_scaled_output"
# input: "/model.22/cv3.2/cv3.2.2/Conv_output_0_bias_reshape_output"
# output: "/model.22/cv3.2/cv3.2.2/Conv_output_0"
# name: "/model.22/cv3.2/cv3.2.2/Conv_output_0_bias_add"
# op_type: "Add"
# , input: "/model.22/cv2.2/cv2.2.2/Conv_output_0"
# input: "/model.22/cv3.2/cv3.2.2/Conv_output_0"
# output: "/model.22/Concat_2_output_0"
# name: "/model.22/Concat_2"
# op_type: "Concat"
# attribute {
#   name: "axis"
#   type: INT
#   i: 1
# }
# , input: "/model.22/Concat_2_output_0"
# input: "/model.22/Constant_output_0"
# output: "/model.22/Reshape_2_output_0"
# name: "/model.22/Reshape_2"
# op_type: "Reshape"
# attribute {
#   name: "allowzero"
#   type: INT
#   i: 0
# }
# , input: "/model.22/Reshape_output_0"
# input: "/model.22/Reshape_1_output_0"
# input: "/model.22/Reshape_2_output_0"
# output: "/model.22/Concat_3_output_0"
# name: "/model.22/Concat_3"
# op_type: "Concat"
# attribute {
#   name: "axis"
#   type: INT
#   i: 2
# }
# , input: "/model.22/Concat_3_output_0"
# input: "onnx::Split_388"
# output: "/model.22/Split_output_0"
# output: "/model.22/Split_output_1"
# name: "/model.22/Split"
# op_type: "Split"
# attribute {
#   name: "axis"
#   type: INT
#   i: 1
# }
# , input: "/model.22/Split_output_0"
# input: "/model.22/dfl/Constant_output_0"
# output: "/model.22/dfl/Reshape_output_0"
# name: "/model.22/dfl/Reshape"
# op_type: "Reshape"
# attribute {
#   name: "allowzero"
#   type: INT
#   i: 0
# }
# , input: "/model.22/Split_output_1"
# output: "/model.22/Sigmoid_output_0"
# name: "/model.22/Sigmoid"
# op_type: "Sigmoid"
# , input: "/model.22/dfl/Reshape_output_0"
# output: "/model.22/dfl/Transpose_output_0"
# name: "/model.22/dfl/Transpose"
# op_type: "Transpose"
# attribute {
#   name: "perm"
#   type: INTS
#   ints: 0
#   ints: 2
#   ints: 1
#   ints: 3
# }
# , input: "/model.22/dfl/Transpose_output_0"
# output: "/model.22/dfl/Softmax_output_0"
# name: "/model.22/dfl/Softmax"
# op_type: "Softmax"
# attribute {
#   name: "axis"
#   type: INT
#   i: 1
# }
# , input: "/model.22/dfl/Softmax_output_0"
# output: "/model.22/dfl/Softmax_output_0_quantized"
# output: "/model.22/dfl/Softmax_output_0_scale"
# output: "/model.22/dfl/Softmax_output_0_zero_point"
# name: "/model.22/dfl/Softmax_output_0_QuantizeLinear"
# op_type: "DynamicQuantizeLinear"
# , input: "/model.22/dfl/Softmax_output_0_scale"
# input: "model.22.dfl.conv.weight_scale"
# output: "/model.22/dfl/conv/Conv_quant_scales_mul:0"
# name: "/model.22/dfl/conv/Conv_quant_scales_mul"
# op_type: "Mul"
# , input: "/model.22/dfl/Softmax_output_0_quantized"
# input: "model.22.dfl.conv.weight_quantized"
# input: "/model.22/dfl/Softmax_output_0_zero_point"
# input: "model.22.dfl.conv.weight_zero_point"
# output: "/model.22/dfl/conv/Conv_output_0_output_quantized"
# name: "/model.22/dfl/conv/Conv_quant"
# op_type: "ConvInteger"
# attribute {
#   name: "dilations"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "group"
#   type: INT
#   i: 1
# }
# attribute {
#   name: "kernel_shape"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# attribute {
#   name: "pads"
#   type: INTS
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
# }
# attribute {
#   name: "strides"
#   type: INTS
#   ints: 1
#   ints: 1
# }
# , input: "/model.22/dfl/conv/Conv_output_0_output_quantized"
# output: "/model.22/dfl/conv/Conv_output_0_output_quantized_cast_output"
# name: "/model.22/dfl/conv/Conv_output_0_output_quantized_cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   type: INT
#   i: 1
# }
# , input: "/model.22/dfl/conv/Conv_output_0_output_quantized_cast_output"
# input: "/model.22/dfl/conv/Conv_quant_scales_mul:0"
# output: "/model.22/dfl/conv/Conv_output_0"
# name: "/model.22/dfl/conv/Conv_quant_output_scale_mul"
# op_type: "Mul"
# , input: "/model.22/dfl/conv/Conv_output_0"
# input: "/model.22/dfl/Constant_1_output_0"
# output: "/model.22/dfl/Reshape_1_output_0"
# name: "/model.22/dfl/Reshape_1"
# op_type: "Reshape"
# attribute {
#   name: "allowzero"
#   type: INT
#   i: 0
# }
# , input: "/model.22/dfl/Reshape_1_output_0"
# input: "/model.22/Constant_4_output_0"
# input: "/model.22/Div_output_0"
# input: "/model.22/Constant_3_output_0"
# output: "/model.22/Slice_output_0"
# name: "/model.22/Slice"
# op_type: "Slice"
# , input: "/model.22/dfl/Reshape_1_output_0"
# input: "/model.22/Div_output_0"
# input: "/model.22/Mul_1_output_0"
# input: "/model.22/Constant_3_output_0"
# output: "/model.22/Slice_1_output_0"
# name: "/model.22/Slice_1"
# op_type: "Slice"
# , input: "/model.22/Constant_9_output_0"
# input: "/model.22/Slice_output_0"
# output: "/model.22/Sub_output_0"
# name: "/model.22/Sub"
# op_type: "Sub"
# , input: "/model.22/Constant_9_output_0"
# input: "/model.22/Slice_1_output_0"
# output: "/model.22/Add_1_output_0"
# name: "/model.22/Add_1"
# op_type: "Add"
# , input: "/model.22/Sub_output_0"
# input: "/model.22/Add_1_output_0"
# output: "/model.22/Add_2_output_0"
# name: "/model.22/Add_2"
# op_type: "Add"
# , input: "/model.22/Add_1_output_0"
# input: "/model.22/Sub_output_0"
# output: "/model.22/Sub_1_output_0"
# name: "/model.22/Sub_1"
# op_type: "Sub"
# , input: "/model.22/Add_2_output_0"
# input: "/model.22/Constant_11_output_0"
# output: "/model.22/Div_1_output_0"
# name: "/model.22/Div_1"
# op_type: "Div"
# , input: "/model.22/Div_1_output_0"
# input: "/model.22/Sub_1_output_0"
# output: "/model.22/Concat_4_output_0"
# name: "/model.22/Concat_4"
# op_type: "Concat"
# attribute {
#   name: "axis"
#   type: INT
#   i: 1
# }
# , input: "/model.22/Concat_4_output_0"
# input: "/model.22/Constant_12_output_0"
# output: "/model.22/Mul_2_output_0"
# name: "/model.22/Mul_2"
# op_type: "Mul"
# , input: "/model.22/Mul_2_output_0"
# input: "/model.22/Sigmoid_output_0"
# output: "output0"
# name: "/model.22/Concat_5"
# op_type: "Concat"
# attribute {
#   name: "axis"
#   type: INT
#   i: 1
# }
# ]

# %% [markdown]
# ## parameters

# %%
print(onnx_model.graph.initializer[0].name)
print([ int(i) for i in onnx_model.graph.initializer[0].raw_data])
# Out:
# model.0.conv.bias
# [139, 117, 248, 63, 180, 95, 36, 64, 42, 27, 200, 63, 80, 218, 232, 63, 93, 76, 209, 64, 227, 98, 150, 63, 108, 202, 108, 64, 6, 62, 51, 64, 31, 91, 252, 63, 235, 137, 169, 63, 80, 141, 1, 64, 192, 200, 22, 64, 11, 147, 14, 191, 39, 198, 229, 63, 105, 40, 34, 192, 141, 184, 198, 63]

# %% [markdown]
# # TensorRt quantization

# %%
from TensorRT import engine
device = 'cuda' if torch.cuda.is_available() else 'cpu'
engine_build = engine.EngineBuilder('models/best.onnx' , device)
engine_build.seg = True
engine_build.build(fp16=True,
              input_shape=[1, 3, 640, 640],
              iou_thres=0.65,
              conf_thres=0.25,
              topk=100)
# Out:
# [09/27/2023-17:24:16] [TRT] [W] onnx2trt_utils.cpp:374: Your ONNX model has been generated with INT64 weights, while TensorRT does not natively support INT64. Attempting to cast down to INT32.
# [09/27/2023-17:24:16] [TRT] [W] input "images" with shape: (1, 3, 640, 640) dtype: DataType.FLOAT
# [09/27/2023-17:24:16] [TRT] [W] output "output0" with shape: (1, 5, 8400) dtype: DataType.FLOAT
# [09/27/2023-17:28:48] [TRT] [W] TensorRT encountered issues when converting weights between types and that could affect accuracy.
# [09/27/2023-17:28:48] [TRT] [W] If this is not the desired behavior, please modify the weights or retrain with regularization to adjust the magnitude of the weights.
# [09/27/2023-17:28:48] [TRT] [W] Check verbose logs for the list of affected weights.
# [09/27/2023-17:28:48] [TRT] [W] - 55 weights are affected by this issue: Detected subnormal FP16 values.
# [09/27/2023-17:28:48] [TRT] [W] - 2 weights are affected by this issue: Detected values less than smallest positive FP16 subnormal value and converted them to the FP16 minimum subnormalized value.
# [09/27/2023-17:28:48] [TRT] [W] Build tensorrt engine finish.
# Save in /home/airi/Mylove/github/facedet_quantization/models/best.engine

# %% [markdown]
# ## model size

# %%
print('size : ' , round(os.path.getsize('models/best.engine')/1024) , 'KB')
# Out:
# size :  8518 KB

# %%
TRT_LOGGER = trt.Logger(trt.Logger.VERBOSE)
runtime = trt.Runtime(TRT_LOGGER)
with open('models/best.engine', 'rb') as f:
    engine_bytes = f.read()
    engine = runtime.deserialize_cuda_engine(engine_bytes)
context = engine.create_execution_context()
# Out:
# [09/27/2023-17:28:48] [TRT] [I] The logger passed into createInferRuntime differs from one already provided for an existing builder, runtime, or refitter. Uses of the global logger, returned by nvinfer1::getLogger(), will return the existing value.
# [09/27/2023-17:28:48] [TRT] [I] Loaded engine size: 8 MiB
# [09/27/2023-17:28:48] [TRT] [V] Deserialization required 22725 microseconds.
# [09/27/2023-17:28:48] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in engine deserialization: CPU +0, GPU +5, now: CPU 0, GPU 5 (MiB)
# [09/27/2023-17:28:48] [TRT] [V] Total per-runner device persistent memory is 0
# [09/27/2023-17:28:48] [TRT] [V] Total per-runner host persistent memory is 359488
# [09/27/2023-17:28:48] [TRT] [V] Allocated activation device memory of size 10035200
# [09/27/2023-17:28:48] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +0, GPU +10, now: CPU 0, GPU 15 (MiB)
# [09/27/2023-17:28:48] [TRT] [V] CUDA lazy loading is enabled.

# %%
names = [engine.get_binding_name(i) for i in range(engine.num_bindings)]
names
# Out:
# /tmp/ipykernel_210101/3033714056.py:1: DeprecationWarning: Use get_tensor_name instead.
#   names = [engine.get_binding_name(i) for i in range(engine.num_bindings)]
# ['images', 'output0']

# %%
print('input shape : ' , tuple(engine.get_binding_shape(0)))
print('output shape : ' , tuple(engine.get_binding_shape(1)) )
# Out:
# input shape :  (1, 3, 640, 640)
# output shape :  (1, 5, 8400)
# /tmp/ipykernel_210101/3611927291.py:1: DeprecationWarning: Use get_tensor_shape instead.
#   print('input shape : ' , tuple(engine.get_binding_shape(0)))
# /tmp/ipykernel_210101/3611927291.py:2: DeprecationWarning: Use get_tensor_shape instead.
#   print('output shape : ' , tuple(engine.get_binding_shape(1)) )

# %% [markdown]
# # Tensorflow quantization

# %%
import tensorflow as tf

# %%
cifar10 = tf.keras.models.load_model('models/cifar10.h5')

# %%
import tensorflow_model_optimization as tfmot
quantize_model = tfmot.quantization.keras.quantize_model
# q_aware stands for for quantization aware.
q_aware_model = quantize_model(cifar10)

# `quantize_model` requires a recompile.
q_aware_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
q_aware_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  quantize_layer (QuantizeLa  (None, 32, 32, 3)         3
#  yer)
#
#  quant_conv2d (QuantizeWrap  (None, 32, 32, 32)        963
#  perV2)
#
#  quant_max_pooling2d (Quant  (None, 16, 16, 32)        1
#  izeWrapperV2)
#
#  quant_conv2d_1 (QuantizeWr  (None, 16, 16, 64)        18627
#  apperV2)
#
#  quant_max_pooling2d_1 (Qua  (None, 8, 8, 64)          1
#  ntizeWrapperV2)
#
#  quant_flatten (QuantizeWra  (None, 4096)              1
#  pperV2)
#
#  quant_dense (QuantizeWrapp  (None, 128)               524421
#  erV2)
#
#  quant_dense_1 (QuantizeWra  (None, 10)                1295
#  pperV2)
#
# =================================================================
# Total params: 545312 (2.08 MB)
# Trainable params: 545098 (2.08 MB)
# Non-trainable params: 214 (856.00 Byte)
# _________________________________________________________________

# %%
q_aware_model.save('quant_models/quant_cifar10.h5')
# Out:
# /home/airi/miniconda3/envs/convert/lib/python3.9/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## model size

# %%
print('cifar10 size : ' , round(os.path.getsize('models/cifar10.h5')/1024) , 'KB')
print('quant_cifar10 size : ' , round(os.path.getsize('quant_models/quant_cifar10.h5')/1024) , 'KB')
# Out:
# cifar10 size :  6431 KB
# quant_cifar10 size :  2179 KB

# %%
q_aware_model.get_weights()
# Out:
# [0.0,
#  0.0,
#  -1,
#  array([[[[   -0.10984,     0.16286,     0.10583,      0.1344,    0.052876,   -0.059854,      0.1234,   -0.048416,     0.14024,    -0.12499,   -0.087416,    -0.01179,   -0.060344,    -0.12102,     0.11035,   -0.054835,     0.10827,  -0.0024675,    0.083012,    -0.18948,    -0.15694,   -0.020592,    -0.17448,
#              0.0057317,  0.00012089,   -0.019303,   -0.044793,    -0.09317,    -0.17016,    -0.14144,    0.040612,   -0.027489],
#           [  -0.029951,  -0.0088726,     -0.0956,     0.14231,    0.072619,      0.1785,     0.14812,     0.13061,   -0.041349,    0.075376,    0.049858,    -0.19289,   -0.096654,    -0.10499,  -0.0057764,    -0.10438,     0.15601,    -0.13745,    0.077967,    -0.14709,    -0.18169,    0.089332,    -0.17634,
#                0.14177,   -0.055198,     0.10172,     0.15777,    0.061197,   -0.081449, -0.00063092,    -0.11247,    0.019658],
#          [[   0.014473,    -0.14576,     -0.0226, ...,   -0.059384,   -0.091984,  -0.0074491],
#           [   -0.11041,    0.035975,   -0.066975, ...,   -0.028457,    -0.14694,    0.085611],
#           [    0.15736,   -0.033019,   -0.035084, ...,   0.0062479,    0.093424,    0.012524],
#           ...,
#           [  -0.071287,     0.17307,  -0.0086094, ...,    0.052312,    0.025872,     0.10699],
#           [    -0.2138,    0.050044,    -0.16997, ...,     0.18887,    -0.18266,     -0.1643],
#           [   0.091932,     0.22282,    0.072069, ...,   -0.072903,    0.020361,    0.063589]],
#
#          [[  -0.059227,  -0.0043209,   -0.028287, ...,  -0.0027759,   -0.046905,   -0.022138],
#           [   -0.13512,    -0.13947,    -0.16026, ...,   -0.024119,    -0.18442,     0.10192],
#           [   0.056317,    -0.08566,     0.06556, ...,    0.076016,    0.068053,     0.17579],
#           ...,
#           [  -0.061096,    0.071961,   -0.089619, ...,    0.065992,    0.024275,    -0.17905],
#           [   -0.16952,     0.14113,   -0.073806, ...,    0.020316,   -0.069776,    -0.22773],
#           [   0.015217,     0.12195,      0.1637, ...,   -0.030214,    -0.06278,    0.092811]]],
#
#
#         [[[    0.10427,    0.085715,    0.079392, ...,   0.0066565,     -0.0638,    0.013312],
#           [  -0.068573,    -0.21915,     0.28939, ...,   -0.073054,   -0.012266,     0.16544],
#           [  -0.048716,    -0.17283,   -0.097383, ...,   -0.068255,    0.077721,    -0.14906],
#           ...,
#           [   0.096576,     0.14085,     0.19189, ...,    0.026052,   -0.071492,     0.29756],
#           [   -0.20843,   -0.045048,   -0.075752, ...,      0.1255,    -0.10455,    0.082667],
#           [  -0.052946,     0.14432,    -0.02178, ...,    -0.25389,   -0.081979,   0.0031109]],
#
#          [[   0.021671,   0.0061661,   -0.056498, ...,    0.036008,   -0.087589,   -0.060457],
#           [   -0.16856,     0.13653,   -0.017019, ...,  -0.0025399,   -0.050858,    0.076058],
#           [   0.010218,   -0.046142,    -0.11609, ...,   -0.059932,    -0.04057,    -0.11393],
#           ...,
#           [  0.0028194,     0.10535,    0.059967, ...,   -0.040705,   -0.051824,    0.018141],
#           [   -0.17284,    -0.10958,   -0.016755, ...,   -0.010049,   -0.017757,     -0.1548],
#           [  -0.073879,     0.20927,   -0.089693, ...,    -0.17971,    -0.05237,    0.027689]],
#
#          [[  -0.045054,   -0.038131,    -0.10859, ...,   -0.020947,    0.024077,   -0.089381],
#           [  -0.059344,    -0.16187,    -0.04688, ...,    0.062771,    -0.11551,    0.011603],
#           [    0.15017,    -0.16481,    0.043536, ...,    0.022278,   -0.042882,     0.14517],
#           ...,
#           [ -0.0087672,   -0.031612,   -0.079563, ...,   -0.023229,    0.093199,    -0.05378],
#           [   -0.22842,     0.25097,   -0.069071, ...,  -0.0049236,   -0.054445,    -0.11942],
#           [   0.015072,     0.21351,   -0.066661, ...,    -0.15219,    -0.12416,   -0.062776]]],
#
#
#         [[[  -0.043484,   -0.086815,   -0.010889, ...,   -0.039953,    0.042242,    0.020662],
#           [  -0.014197,    -0.10055,       0.249, ...,    0.015725,    0.052843,    0.053001],
#           [   -0.12886,    0.086978,    -0.14721, ...,    -0.10929,      0.1029,    -0.10748],
#           ...,
#           [   0.072217,   -0.030753,     0.11414, ...,   -0.082519,    0.065754,     0.13488],
#           [   0.026286,    -0.11278,    0.072922, ...,   -0.055637,     0.14596,   -0.023686],
#           [  -0.066753,  -0.0030109,   0.0036646, ...,   -0.097377,    0.020101,   -0.013752]],
#
#          [[   0.013285,   -0.089702,    0.026183, ...,    0.023701,      0.1322,    -0.12855],
#           [  -0.058419,    0.012989,   -0.017126, ...,    -0.06096,   -0.008831,   -0.019942],
#           [   -0.15692,     0.10247,     -0.1318, ...,    -0.20589,   -0.088697,   -0.057203],
#           ...,
#           [   0.079084,    -0.11016,    0.082285, ...,   0.0026676,    0.074562,    0.036537],
#           [   -0.11545,    -0.14918,     0.08843, ...,  -0.0098945,    0.062853,    -0.24297],
#           [    0.10999,    0.018046,    -0.10938, ...,   -0.050576,   -0.077347,    0.017724]],
#
#          [[   -0.11624,    -0.14561,   -0.014976, ...,    0.075555,   -0.035083,    -0.18664],
#           [  -0.046568,      -0.194,   -0.053971, ...,    0.043304,     0.20073,     0.07989],
#           [  -0.039055,   -0.022921,     -0.1177, ...,   -0.074284,   -0.064958,     0.12845],
#           ...,
#           [    0.10259,   -0.054516,   -0.077467, ...,   -0.050081,    0.097105,     -0.1657],
#           [   -0.11124,      0.2863,    0.035061, ...,    0.030019,   -0.079151,   -0.060963],
#           [ 0.00048105,    0.049884,    0.073687, ...,   -0.042301,   -0.007902,    0.081824]]]], dtype=float32),
#  array([     0.0271,    -0.04547,    0.026399,     0.11534,   -0.013266,    0.043835,    0.033205,   -0.011977,   -0.031365,   -0.080707,    0.063519,   -0.023429,   -0.021973,    0.039156,   -0.048153,    0.023049,   -0.019148,    0.043062,   -0.060229,       0.128,  -0.0070987,   -0.041948,    0.011633,    0.046323,
#           -0.045769,     0.19683,   -0.046783,    0.033501,   -0.015878,    0.020371,    0.051228,    0.049802,    0.016953,   -0.031479,   -0.061534,    0.054525,  -0.0060957,    0.001671,   -0.063945,    0.029225,     0.07754,   -0.016314,   0.0056196,    0.066882,     0.10195,   -0.076599,    0.063766,   -0.013001,
#           0.0078784, -0.00025369,   -0.022945,     0.04502,    0.094794,    0.024474,   -0.040729,    0.051766,     -0.0716,    0.023479,     0.02772,   -0.022268,   -0.012521,   0.0042134,    0.019557,    0.018785], dtype=float32),
#  -1,
#  array([         -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,
#                  -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,
#                  -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6,          -6], dtype=float32),
#  array([          6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,
#                   6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,
#                   6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6,           6], dtype=float32),
#  -6.0,
#  6.0,
#  -1,
#  -1,
#  array([[  0.0061698,   -0.020498,   -0.031607, ...,   -0.036613,   -0.033058,     0.02355],
#         [  -0.019263,   -0.068637,  -0.0079766, ...,   0.0061821,   -0.036255,    0.011557],
#         [   0.034327,   -0.033028,     0.02689, ...,  -0.0080502,   -0.037835,     0.01934],
#         ...,
